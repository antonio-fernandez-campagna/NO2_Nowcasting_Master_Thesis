# %%
import pandas as pd
import os

# %% [markdown]
# ## Data Reading

# %%
df_mapping_no2_to_traffico = pd.read_csv("../../data/processed/mapping/no2_to_traffic_sensor_mapping.csv")

df_air_quality_and_locations = pd.read_parquet("../../data/processed/air/df_air_quality_and_locations_from_2013.parquet")

# %%
# Define the root directory for processed traffic data
root_dir = '../../data/processed/traffic'

# List to hold DataFrames
dataframes = []

# Iterate through all folders in the root directory
for folder_name in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder_name)
    
    # Check if the folder exists and is a directory
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder_path}")
        
        # Iterate through all files in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.parquet'):  # Ensure it's a Parquet file
                file_path = os.path.join(folder_path, file_name)
                
                # Read the Parquet file
                try:
                    df = pd.read_parquet(file_path)
                    print(f"Successfully read: {file_path} with {len(df)} rows.")
                    
                    # Append the DataFrame to the list
                    dataframes.append(df)
                    
                except Exception as e:
                    print(f"Error reading file {file_name}: {e}")

# Concatenate all DataFrames into one
if dataframes:  # Check if the list is not empty
    df_traffic = pd.concat(dataframes, ignore_index=True)
    print(f"Combined DataFrame created with {len(df_traffic)} rows.")
# Out:
# Processing folder: ../../data/processed/traffic/2022
# Successfully read: ../../data/processed/traffic/2022/12-2022_processed.parquet with 48331 rows.
# Successfully read: ../../data/processed/traffic/2022/11-2022_processed.parquet with 46722 rows.
# Successfully read: ../../data/processed/traffic/2022/10-2022_processed.parquet with 47576 rows.
# Successfully read: ../../data/processed/traffic/2022/01-2022_processed.parquet with 45047 rows.
# Successfully read: ../../data/processed/traffic/2022/06-2022_processed.parquet with 42196 rows.
# Successfully read: ../../data/processed/traffic/2022/05-2022_processed.parquet with 42735 rows.
# Successfully read: ../../data/processed/traffic/2022/08-2022_processed.parquet with 45087 rows.
# Successfully read: ../../data/processed/traffic/2022/02-2022_processed.parquet with 40460 rows.
# Successfully read: ../../data/processed/traffic/2022/03-2022_processed.parquet with 44372 rows.
# Successfully read: ../../data/processed/traffic/2022/09-2022_processed.parquet with 46207 rows.
# Successfully read: ../../data/processed/traffic/2022/04-2022_processed.parquet with 42616 rows.
# Successfully read: ../../data/processed/traffic/2022/07-2022_processed.parquet with 44018 rows.
# Processing folder: ../../data/processed/traffic/2024
# Successfully read: ../../data/processed/traffic/2024/10-2024_processed.parquet with 45475 rows.
# Successfully read: ../../data/processed/traffic/2024/09_2024_processed.parquet with 44131 rows.
# Successfully read: ../../data/processed/traffic/2024/11-2024_processed.parquet with 43539 rows.
# Successfully read: ../../data/processed/traffic/2024/12-2024_processed.parquet with 44869 rows.
# Successfully read: ../../data/processed/traffic/2024/07-2024_processed.parquet with 46142 rows.
# Successfully read: ../../data/processed/traffic/2024/04-2024_processed.parquet with 46185 rows.
# Successfully read: ../../data/processed/traffic/2024/03-2024_processed.parquet with 47787 rows.
# Successfully read: ../../data/processed/traffic/2024/08-2024_processed.parquet with 46974 rows.
# Successfully read: ../../data/processed/traffic/2024/02-2024_processed.parquet with 44676 rows.
# Successfully read: ../../data/processed/traffic/2024/05-2024_processed.parquet with 46887 rows.
# Successfully read: ../../data/processed/traffic/2024/06-2024_processed.parquet with 45093 rows.
# Successfully read: ../../data/processed/traffic/2024/01-2024_processed.parquet with 48040 rows.
# Processing folder: ../../data/processed/traffic/2023
# Successfully read: ../../data/processed/traffic/2023/11-2023_processed.parquet with 45523 rows.
# Successfully read: ../../data/processed/traffic/2023/12-2023_processed.parquet with 47876 rows.
# Successfully read: ../../data/processed/traffic/2023/10-2023_processed.parquet with 45348 rows.
# Successfully read: ../../data/processed/traffic/2023/05-2023_processed.parquet with 47733 rows.
# Successfully read: ../../data/processed/traffic/2023/08-2023_processed.parquet with 45418 rows.
# Successfully read: ../../data/processed/traffic/2023/02-2023_processed.parquet with 43412 rows.
# Successfully read: ../../data/processed/traffic/2023/01-2023_processed.parquet with 48273 rows.
# Successfully read: ../../data/processed/traffic/2023/06-2023_processed.parquet with 45088 rows.
# Successfully read: ../../data/processed/traffic/2023/07-2023_processed.parquet with 45591 rows.
# Successfully read: ../../data/processed/traffic/2023/03-2023_processed.parquet with 48112 rows.
# Successfully read: ../../data/processed/traffic/2023/09-2023_processed.parquet with 44461 rows.
# Successfully read: ../../data/processed/traffic/2023/04-2023_processed.parquet with 46202 rows.
# Processing folder: ../../data/processed/traffic/2019
# Successfully read: ../../data/processed/traffic/2019/01-2019_processed.parquet with 39596 rows.
# Successfully read: ../../data/processed/traffic/2019/06-2019_processed.parquet with 36510 rows.
# Successfully read: ../../data/processed/traffic/2019/05-2019_processed.parquet with 36285 rows.
# Successfully read: ../../data/processed/traffic/2019/02-2019_processed.parquet with 34803 rows.
# Successfully read: ../../data/processed/traffic/2019/08-2019_processed.parquet with 37917 rows.
# Successfully read: ../../data/processed/traffic/2019/09-2019_processed.parquet with 36701 rows.
# Successfully read: ../../data/processed/traffic/2019/03-2019_processed.parquet with 36931 rows.
# Successfully read: ../../data/processed/traffic/2019/04-2019_processed.parquet with 34407 rows.
# Successfully read: ../../data/processed/traffic/2019/07-2019_processed.parquet with 38182 rows.
# Successfully read: ../../data/processed/traffic/2019/12-2019_processed.parquet with 38639 rows.
# Successfully read: ../../data/processed/traffic/2019/11-2019_processed.parquet with 38137 rows.
# Successfully read: ../../data/processed/traffic/2019/10-2019_processed.parquet with 39175 rows.
# Processing folder: ../../data/processed/traffic/2021
# Successfully read: ../../data/processed/traffic/2021/10-2021_processed.parquet with 41419 rows.
# Successfully read: ../../data/processed/traffic/2021/11-2021_processed.parquet with 40748 rows.
# Successfully read: ../../data/processed/traffic/2021/12-2021_processed.parquet with 45004 rows.
# Successfully read: ../../data/processed/traffic/2021/07-2021_processed.parquet with 39032 rows.
# Successfully read: ../../data/processed/traffic/2021/03-2021_processed.parquet with 36675 rows.
# Successfully read: ../../data/processed/traffic/2021/09-2021_processed.parquet with 38297 rows.
# Successfully read: ../../data/processed/traffic/2021/04-2021_processed.parquet with 35328 rows.
# Successfully read: ../../data/processed/traffic/2021/05-2021_processed.parquet with 37858 rows.
# Successfully read: ../../data/processed/traffic/2021/08-2021_processed.parquet with 39345 rows.
# Successfully read: ../../data/processed/traffic/2021/02-2021_processed.parquet with 33489 rows.
# Successfully read: ../../data/processed/traffic/2021/01-2021_processed.parquet with 34287 rows.
# Successfully read: ../../data/processed/traffic/2021/06-2021_processed.parquet with 35442 rows.
# Processing folder: ../../data/processed/traffic/2020
# Successfully read: ../../data/processed/traffic/2020/10-2020_processed.parquet with 37146 rows.
# Successfully read: ../../data/processed/traffic/2020/12-2020_processed.parquet with 36801 rows.
# Successfully read: ../../data/processed/traffic/2020/11-2020_processed.parquet with 36843 rows.
# Successfully read: ../../data/processed/traffic/2020/03-2020_processed.parquet with 37283 rows.
# Successfully read: ../../data/processed/traffic/2020/09-2020_processed.parquet with 35380 rows.
# Successfully read: ../../data/processed/traffic/2020/04-2020_processed.parquet with 35347 rows.
# Successfully read: ../../data/processed/traffic/2020/07-2020_processed.parquet with 37325 rows.
# Successfully read: ../../data/processed/traffic/2020/01-2020_processed.parquet with 37937 rows.
# Successfully read: ../../data/processed/traffic/2020/06-2020_processed.parquet with 35622 rows.
# Successfully read: ../../data/processed/traffic/2020/05-2020_processed.parquet with 35734 rows.
# Successfully read: ../../data/processed/traffic/2020/08-2020_processed.parquet with 36788 rows.
# Successfully read: ../../data/processed/traffic/2020/02-2020_processed.parquet with 35706 rows.
# Processing folder: ../../data/processed/traffic/2018
# Successfully read: ../../data/processed/traffic/2018/05-2018_processed.parquet with 39368 rows.
# Successfully read: ../../data/processed/traffic/2018/02-2018_processed.parquet with 36471 rows.
# Successfully read: ../../data/processed/traffic/2018/08-2018_processed.parquet with 40184 rows.
# Successfully read: ../../data/processed/traffic/2018/01-2018_processed.parquet with 39973 rows.
# Successfully read: ../../data/processed/traffic/2018/06-2018_processed.parquet with 38895 rows.
# Successfully read: ../../data/processed/traffic/2018/07-2018_processed.parquet with 40112 rows.
# Successfully read: ../../data/processed/traffic/2018/09-2018_processed.parquet with 35822 rows.
# Successfully read: ../../data/processed/traffic/2018/03-2018_processed.parquet with 40240 rows.
# Successfully read: ../../data/processed/traffic/2018/04-2018_processed.parquet with 38213 rows.
# Successfully read: ../../data/processed/traffic/2018/11-2018_processed.parquet with 34805 rows.
# Successfully read: ../../data/processed/traffic/2018/12-2018_processed.parquet with 38299 rows.
# Successfully read: ../../data/processed/traffic/2018/10-2018_processed.parquet with 36567 rows.
# Combined DataFrame created with 3439270 rows.

# %%
df_traffic = df_traffic.rename(columns = {'hora': 'fecha'})

# %%
df_traffic.to_parquet("traffic_data.parquet", index = False)

# %%
df_traffic.fecha.min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %% [markdown]
# ## Data processing for NO2 Sensores

# %% [markdown]
# 1. Eliminar del dataset todos los sensores que no esten dentro del dataset "df_mapping_no2_to_traffico".
# para ello, compara del dataset df_mapping_no2_to_traffico columna id_no2 con dataset df_air_quality_and_locations "CODIGO".

# %%
# Filter df_air_quality_and_locations to keep only sensors present in df_mapping_no2_to_traffico
filtered_air_quality_data = df_air_quality_and_locations[
    df_air_quality_and_locations['CODIGO'].isin(df_mapping_no2_to_traffico['id_no2'])
]

# %%
# Get the length of the original DataFrame
original_count = len(df_air_quality_and_locations)

# Get the length of the filtered DataFrame
filtered_count = len(filtered_air_quality_data)

# Calculate the percentage of retained sensors
percentage_retained = (filtered_count / original_count) * 100

print(f'Number of original sensors: {original_count}')
print(f'Number of retained sensors: {filtered_count}')
print(f'Percentage of retained data: {percentage_retained:.2f}%')
# Out:
# Number of original sensors: 2490936
# Number of retained sensors: 1343640
# Percentage of retained data: 53.94%

# %% [markdown]
# Let's remove unnecesary columns:

# %%
unnecesary_cols = ['PROVINCIA','MUNICIPIO','ESTACION','MAGNITUD','PUNTO_MUESTREO','CODIGO_CORTO','LOCALIZACION','DIRECCION','COD_VIA','COD_TIPO']

# %%
df_air = filtered_air_quality_data.drop(columns = unnecesary_cols)
df_air.columns = df_air.columns.str.lower()
df_air = df_air.rename(columns = {'codigo':'id_no2'})

# %% [markdown]
# # Creating the main dataset

# %% [markdown]
# ### Approach 1: Count the period for each `ID_trafffic sensors`

# %%
# Create a new dataframe with the following structure, for each unique traffic sensor (id_trafico)

# id_traffico, year, month, appears
# 3411, 2024, 11, true
# 3411, 2024, 12, false
df = df_traffic.copy()

# Convert fecha to datetime
df["fecha"] = pd.to_datetime(df["fecha"])

# Extract year and month
df["year"] = df["fecha"].dt.year
df["month"] = df["fecha"].dt.month

# Create the new DataFrame with unique combinations
result = df.groupby(["id_trafico", "year", "month"]).size().reset_index(name="count")

# Add 'appears' column (True if there is data for that month)
result["appears"] = result["count"] > 500

# Drop the count column as it's not needed
result = result.drop(columns=["count"])

result.sort_values(by=['year', 'month', 'id_trafico'])

result = result[result['appears'] == True]

# %%
df_summary = result.groupby('id_trafico').agg(
    start=('year', lambda x: f"{x.iloc[0]}-{df.loc[x.index[0], 'month']:02d}"),
    end=('year', lambda x: f"{x.iloc[-1]}-{df.loc[x.index[-1], 'month']:02d}")
).reset_index()

# %% [markdown]
# ensure that each sensors has continuous data, you can see the year and month, check the max, check the min and create a new df for each sensor and a new variable: is_continuous

# %%
#df_summary.to_csv("traffic_sensor_periods.csv", index = False)

# %%
result[result['id_trafico'] == '6119'].sort_values(by=['year', 'month']).drop(columns = ['appears'])
# Out:
#      id_trafico  year  month
# 4502       6119  2018      1
# 4503       6119  2018      2
# 4504       6119  2018      3
# 4505       6119  2018      4
# 4506       6119  2018      5
# ...         ...   ...    ...
# 4581       6119  2024      8
# 4582       6119  2024      9
# 4583       6119  2024     10
# 4584       6119  2024     11
# 4585       6119  2024     12
#
# [76 rows x 3 columns]

# %%
def check_continuity(group):
    group = group.sort_values(['year', 'month'])
    
    # Create a full range of expected periods
    min_date = f"{group['year'].min()}-{group['month'].min()}-01"
    max_date = f"{group['year'].max()}-{group['month'].max()}-01"
    expected_range = pd.date_range(start=min_date, end=max_date, freq='MS').to_period('M')
    
    # Get actual periods in the dataset
    actual_range = pd.to_datetime(group[['year', 'month']].assign(day=1)).dt.to_period('M')
    
    # Check if the sets are equal
    is_continuous = set(expected_range) == set(actual_range)
    
    return pd.Series({
        'start': group.iloc[0][['year', 'month']].astype(str).str.cat(sep='-'),
        'end': group.iloc[-1][['year', 'month']].astype(str).str.cat(sep='-'),
        'is_continuous': is_continuous
    })

# Apply function to each sensor
df_final = result.groupby('id_trafico').apply(check_continuity).reset_index()
# Out:
# /var/folders/kc/t6c9n8gj7mbblj0w7sy3ykwm0000gn/T/ipykernel_11174/898840416.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_final = result.groupby('id_trafico').apply(check_continuity).reset_index()

# %%
df_traffic[(df_traffic['id_trafico'] == '6123') & 
                               (df_traffic['fecha'].dt.year == 2019) & 
                               (df_traffic['fecha'].dt.month == 3)]
# Out:
#         id_trafico               fecha  intensidad      carga  ocupacion  vmed
# 1894673       6123 2019-03-01 00:00:00       79.75   4.341693   0.313480   0.0
# 1894674       6123 2019-03-01 01:00:00       39.00   2.903846   0.544872   0.0
# 1894675       6123 2019-03-01 02:00:00       25.75   1.757282   0.000000   0.0
# 1894676       6123 2019-03-01 03:00:00       24.00   0.802083   0.000000   0.0
# 1894677       6123 2019-03-01 04:00:00       12.00   0.541667   0.000000   0.0
# ...            ...                 ...         ...        ...        ...   ...
# 1894757       6123 2019-03-04 12:00:00        0.00   0.000000   0.000000   0.0
# 1894758       6123 2019-03-04 13:00:00      120.00  14.000000  26.000000   0.0
# 1894759       6123 2019-03-12 08:00:00        0.00   0.000000   0.000000   0.0
# 1894760       6123 2019-03-13 16:00:00        0.00   0.000000   0.000000   0.0
# 1894761       6123 2019-03-31 08:00:00        0.00   0.000000   0.000000   0.0
#
# [89 rows x 6 columns]

# %%
#result[result['id_trafico'] == '6123'].sort_values(by=['year', 'month']).to_csv("test.csv", index = False)

# %%
#a = pd.read_csv('../../data/raw/traffic/2019/03-2019.csv',delimiter= ";")

# %%
#a[a['id'] == 6123].sort_values(by='fecha')

# %% [markdown]
# `Solo los sensores 5547, 5783, 5465, 5414, 5084, 4555, 4129, 3915, 3911, van del 2018-01 al 2024-12`

# %%
result.id_trafico.unique()
# Out:
# array(['10250', '10332', '10580', '10613', '10614', '10615', '10647',
#        '10814', '10885', '10889', '10890', '10982', '11006', '11007',
#        '3411', '3513', '3730', '3731', '3732', '3791', '3910', '3911',
#        '3913', '3914', '3915', '3916', '3917', '4022', '4026', '4027',
#        '4028', '4048', '4129', '4283', '4284', '4285', '4286', '4301',
#        '4303', '4313', '4333', '4353', '4437', '4461', '4469', '4472',
#        '4555', '5084', '5090', '5091', '5414', '5415', '5416', '5421',
#        '5422', '5437', '5465', '5515', '5547', '5783', '5784', '5939',
#        '6116', '6118', '6119', '6123', '6822', '6823', '7071'],
#       dtype=object)

# %%
df_final
# Out:
#    id_trafico    start      end  is_continuous
# 0       10250  2018-12   2024-9          False
# 1       10332   2018-6   2018-8           True
# 2       10580   2020-7   2024-9          False
# 3       10613   2020-8  2024-12          False
# 4       10614   2020-8  2024-12          False
# ..        ...      ...      ...            ...
# 64       6119   2018-1  2024-12          False
# 65       6123   2018-1  2024-12          False
# 66       6822   2018-1  2024-12          False
# 67       6823   2018-1  2024-12          False
# 68       7071   2018-1  2024-12          False
#
# [69 rows x 4 columns]

# %%
result.drop(columns = 'appears')
# Out:
#      id_trafico  year  month
# 1         10250  2018     12
# 2         10250  2019      1
# 3         10250  2019      2
# 4         10250  2019      3
# 5         10250  2019      4
# ...         ...   ...    ...
# 4905       7071  2024      8
# 4906       7071  2024      9
# 4907       7071  2024     10
# 4908       7071  2024     11
# 4909       7071  2024     12
#
# [4710 rows x 3 columns]

# %%
df_traffic[df_traffic['id_trafico'] == '4303'].drop(columns = ['intensidad','carga','ocupacion','vmed'])
# Out:
#         id_trafico               fecha
# 26768         4303 2022-12-01 00:00:00
# 26769         4303 2022-12-01 01:00:00
# 26770         4303 2022-12-01 02:00:00
# 26771         4303 2022-12-01 03:00:00
# 26772         4303 2022-12-01 04:00:00
# ...            ...                 ...
# 3418526       4303 2018-10-24 05:00:00
# 3418527       4303 2018-10-24 06:00:00
# 3418528       4303 2018-10-24 07:00:00
# 3418529       4303 2018-10-24 08:00:00
# 3418530       4303 2018-10-24 09:00:00
#
# [52670 rows x 2 columns]
